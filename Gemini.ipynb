# %%
pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyBg89Y0qURC2ddW5TixTsXktIePOWTDqr8")

# %%
for i in genai.list_models():
  print (i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# ...

# %%
model=genai.GenerativeModel("gemini-pro")

# %%
res=model.generate_content("List out the district in tamilnadu")

# %%
res
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "1. Ariyalur\n2. Chennai\n3. Coimbatore\n4. Cuddalore\n5. Dharmapuri\n6. Dindigul\n7. Erode\n8. Kanchipuram\n9. Kanyakumari\n10. Karur\n11. Krishnagiri\n12. Madurai\n13. Nagapattinam\n14. Nilgiris\n15. Namakkal\n16. Perambalur\n17. Pudukkottai\n18. Ramanathapuram\n19. Salem\n20. Sivaganga\n21. Tenkasi\n22. Thanjavur\n23. Theni\n24. Tiruchirappalli\n25. Tirunelveli\n26. Tiruppur\n27. Tiruvallur\n28. Thoothukudi\n29. Vellore\n30. Villupuram\n31. Virudhunagar"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0,
#           "safety_ratings": [
#             {
#               "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
# ...

# %%
res.text
# Out:
# '**Northern Districts:**\n\n* Chennai\n* Chengalpattu\n* Kanchipuram\n* Tiruvallur\n* Vellore\n\n**Southern Districts:**\n\n* Madurai\n* Theni\n* Dindigul\n* Ramanathapuram\n* Thoothukudi\n\n**Western Districts:**\n\n* Coimbatore\n* Tiruppur\n* Nilgiris\n* Erode\n* Salem\n\n**Eastern Districts:**\n\n* Thanjavur\n* Tiruvarur\n* Nagapattinam\n* Cuddalore\n* Villupuram\n\n**Central Districts:**\n\n* Trichy\n* Perambalur\n* Ariyalur\n* Karur\n* Pudukkottai\n\n**Other Districts:**\n\n* Kanyakumari\n* Sivagangai\n* Virudhunagar'

# %%
res=model.generate_content("list out the tamil movie names")
print(res.text)
# Out:
# * 96
# * Aparichit
# * Asuran
# * Bigil
# * Boys
# * Chennai 28
# * Cheran Pandiyan
# * Deiva Thirumagal
# * Enthiran
# * Ghajini
# * I
# * Jilla
# * Kabali
# * Kaithi
# * Kanna Laddu Thinna Aasaiya
# * Karnan
# * Kattradhu Thamizh
# * Kumki
# * Madras
# * Maanagaram
# * Master
# * Mersal
# * Moodar Koodam
# * Mouna Raagam
# * Nayakan
# * Nerkonda Paarvai
# * Paruthiveeran
# * Pizza
# * Pollachi Mappillai
# * Ponniyin Selvan
# * Premam
# * Pudhupettai
# * Pulimurugan
# * Rajinikanth
# * Raatchasan
# * Remo
# * Saamy
# * Sarpatta Parambarai
# * Sethu
# * Sivaji
# * Soorarai Pottru
# * Subramaniapuram
# * Tamizh Padam
# * Thani Oruvan
# * Thiruttu Payale
# * Tik Tik Tik
# * To Let
# * Vaaranam Aayiram
# * Vikram
# * Vinnaithaandi Varuvaaya
# * Viswasam
# * Yogi

# %%
vision_model=genai.GenerativeModel("gemini-1.0-pro-001")

# %%
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.0-pro-001',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image

# %%
img=Image.open("/content/computer.webp")

# %%
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1400x900>

# %%
vision_model=genai.GenerativeModel("gemini-1.5-pro-latest")

# %%
res=vision_model.generate_content(["explain in this image",Image.open("/content/computer.webp")])
print(res.text)
# Out:
# This image is a visual metaphor for the interconnectedness of hardware and software in modern computing.  Here's a breakdown:
#
# * **Laptop:** Represents the physical hardware, the tangible device we interact with.
# * **Circuit Board Pattern on Screen & Surface:** Symbolizes the underlying electronic circuitry that powers the laptop and all computing devices. It's a reminder that even though we interact primarily with software, it's all built upon a foundation of hardware.
# * **Glowing Center on the Screen & Data Streams:**  Suggests data processing and the flow of information.  The glowing area could represent the CPU or a central processing point. The streams visualize data moving within the system, perhaps between different components or to and from the network.
# ...
